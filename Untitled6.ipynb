# %% [markdown]
# <a href="https://colab.research.google.com/github/tanishqpanipat/AIML/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
url = 'https://raw.githubusercontent.com/tanishqpanipat/AIML/main/bmi_train.csv'
df = pd.read_csv(url)

# %%
df
# Out:
#     Gender  Height  Weight  Index
# 0     Male     161      89      4
# 1     Male     179     127      4
# 2     Male     172     139      5
# 3     Male     153     104      5
# 4     Male     165      68      2
# ..     ...     ...     ...    ...
# 395   Male     166     160      5
# 396   Male     145     130      5
# 397   Male     178     138      5
# 398   Male     168     158      5
# 399   Male     161     155      5
#
# [400 rows x 4 columns]

# %%
df.head()
# Out:
#   Gender  Height  Weight  Index
# 0   Male     161      89      4
# 1   Male     179     127      4
# 2   Male     172     139      5
# 3   Male     153     104      5
# 4   Male     165      68      2

# %%
df['Height'].fillna(df['Height'].mean(),inplace=True)
#df['MetaScore'].fillna(df['MetaScore'].median(),inplace=True)

# %%
df
# Out:
#     Gender  Height  Weight  Index
# 0     Male     161      89      4
# 1     Male     179     127      4
# 2     Male     172     139      5
# 3     Male     153     104      5
# 4     Male     165      68      2
# ..     ...     ...     ...    ...
# 395   Male     166     160      5
# 396   Male     145     130      5
# 397   Male     178     138      5
# 398   Male     168     158      5
# 399   Male     161     155      5
#
# [400 rows x 4 columns]

# %%
df.corr()
# Out:
# <ipython-input-10-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#           Height    Weight     Index
# Height  1.000000  0.033126 -0.407796
# Weight  0.033126  1.000000  0.801521
# Index  -0.407796  0.801521  1.000000

# %%
df.columns
# Out:
# Index(['Gender', 'Height', 'Weight', 'Index'], dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df[['Weight']] = scaler.fit_transform(df[['Weight']])

# %%
df['Weight']
# Out:
# 0      0.354545
# 1      0.700000
# 2      0.809091
# 3      0.490909
# 4      0.163636
#          ...
# 395    1.000000
# 396    0.727273
# 397    0.800000
# 398    0.981818
# 399    0.954545
# Name: Weight, Length: 400, dtype: float64

# %%
#checking if threre are duplicates or not
a = df.duplicated().any()
#print(a)
if(a):
    print('There are duplicates')
else:
    print('No duplicates')
# Out:
# There are duplicates

# %%
#Detecting outliers
q1=df.quantile(0.25)
q3=df.quantile(0.75)
iqr=q3-q1
outliers=(df>q3+3*iqr) | (df<q1-3*iqr)
k=outliers.sum()
print(k)
# Out:
# Gender    0
# Height    0
# Index     0
# Weight    0
# dtype: int64
# <ipython-input-15-d377320daa2c>:2: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   q1=df.quantile(0.25)
# <ipython-input-15-d377320daa2c>:3: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   q3=df.quantile(0.75)
# <ipython-input-15-d377320daa2c>:5: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   outliers=(df>q3+3*iqr) | (df<q1-3*iqr)

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Create a contingency table between 'Height' and 'Weight'
contingency_table = pd.crosstab(df['Height'], df['Weight'])

# Perform the chi-square test
chi2, p, _, _ = chi2_contingency(contingency_table)

# Print the results
print(f"Chi-square statistic: {chi2}")
print(f"P-value: {p}")

# Interpret the results (e.g., check if p < 0.05 for significance)
if p < 0.05:
    print("There is a significant association between Height and Weight.")
else:
    print("There is no significant association between Height and Weight.")
# Out:
# Chi-square statistic: 6488.413626056483
# P-value: 0.3048084908602765
# There is no significant association between Height and Weight.
